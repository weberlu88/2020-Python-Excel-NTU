# %% [markdown]
# ## 雖然我們已經寫好了程式...
#
# 今天當我們把程式寫好之後，接下來我們只需要執行程式，就可以透過 Fugle API 把資料截取至工作表内
#
# 但是，很多時候**我們總是會忘記定期執行程式**，要是忘記一天，最後會造成**資料的缺失**，導致程式出錯
#
# 因此，若我們能夠讓電腦定期去執行我們寫好的 Python 程式，就能夠將搜集資料這件事給完全的自動化了
#
# ## 電腦排程
#
# 這邊就跟大家介紹一下排程，換句話説，就是一個能夠電腦**定期在我們指定的時間去執行某一件事情的功能**
#
# 接下來的教學會先以 Windows OS 爲主
#
# ## 下載檔案
#
# 在我們開始設定排程之前，我們需要先能夠讓我們的 Python 程式碼在命令提示字元 / 終端機上執行
#
# 請下載我們這節課教材的完整版程式碼 (.py 檔案)：[下載連結](https://drive.google.com/open?id=14UBgHaanCzbJJXKhVaxf5lvNdf6aHxAJ)
#
# - **tw_stock_backtest.py**
# - **stock_portfolio_backtest.xlsx**
#
# 請將這兩個檔案放置同一個資料夾

# %% [markdown]
# ## 設定Excel 檔案路徑
#
#
# 在檔案總管找到**stock_portfolio_backtest.xlsx**，並且左鍵選擇内容 > 安全性，複製該檔案的絕對路徑：
# ![](https://drive.google.com/uc?export=download&id=17GVNOADMYEVUq7vAYpVNKn0V-cytKd7E)
#
# 接下來請開啓檔案，修改程式碼的 Excel 檔案路徑，將檔案路徑設定成剛才複製的絕對路徑
#
# 範例：
# ![](https://drive.google.com/uc?export=download&id=1VSg5GyyRRRqo-uuChRAuxkX2auTS6UvV)
#
# 在檔案總管找到 **tw_stock_backtest.py**，並且左鍵選擇内容 > 安全性，複製該檔案的絕對路徑：
#
# ![](https://drive.google.com/uc?export=download&id=1xI26Uwr8tXtjHskfSTwbXP0vFI8LlErs)
#
# 接下來請在 Jupyter Notebook 執行以下指令，找出 Python.exe 應用程式的路徑：
#
# ```bash
# !where python
# ```

# %%
# !C:\ProgramData\Anaconda3\python.exe "C:\Users\yuyue\OneDrive\桌面\Fugle_Line_class\第二課\daily_tw_stock_updater_v2.py"

# %%
# !where python

# %% [markdown]
# 拼凑出執行程式的指令：
# ```bash
# python.exe的路徑 tw_stock_backtest.py 檔案的路徑
# ```
# ## 範例：
#
# ```bash
# !C:\ProgramData\Anaconda3\python.exe C:\Users\yuyue\OneDrive\桌面\30hr_pyxl\python_excel_lesson5\tw_stock_backtest.py
# ```
#
# *請注意兩個路徑之間要空格
#
# 接下來請先在下面的儲存格測試指令是否可以執行成功
#
# *使用 Windows 的同學，若執行時顯示 OpenSSL 的錯誤，請到以下連結下載 OpenSSL:
#
# [OpenSSL 下載連結](https://slproweb.com/products/Win32OpenSSL.html)

# %% [markdown]
# ## 接下來請開啓 cmd (命令提示字元) 應用程式
#
# 我們要確認同樣的指令能夠在命令提示字元上執行成功，請將剛才的指令輸入至：
#
# ![](https://drive.google.com/uc?export=download&id=1ULEMT03TK77e5GA7VoTNbIdLuPNMdtxv)
#
# 並且能執行成功：
#
# ![](https://drive.google.com/uc?export=download&id=1VXg_7EjA2sLKsEHh5UyjNXjdm1i2UxYd)
#
# 若我們在確認該指令可以執行成功後，接下來我們就來設定排程吧

# %% [markdown]
# ## 首先請在 Windows 搜尋"工作排程器"
#
# 選擇**建立工作**：
#
# ![](https://drive.google.com/uc?export=download&id=1nEpdr-xYGwncD9CsUbb5xggu5px_8i2b)

# %% [markdown]
# # 我們需要完成的設定：
#
# 1. 名稱
# 2. 觸發程序（在什麽時候需要執行）
# 3. 動作（需要執行的指令）
#
# ## 接下來我們就來幫即將建立的工作取一個名字
#
# ![](https://drive.google.com/uc?export=download&id=1iiyqf-0OdtT8bshdtK8AYvwLVUXI8kpJ)
#
# ## 接下來我們切換至觸發程序
#
# ![](https://drive.google.com/uc?export=download&id=1KQO3JnXgIddWc62rVBCG-vd3Gv-PXMw9)
#
# ## 設定每次執行的時間，以及執行的頻率
#
# ![](https://drive.google.com/uc?export=download&id=1eDbEFyJ8mpZRpfuPDdhd_mjbwSH2nJ0b)
#
#
# ## 接下來我們點選動作，設定需要執行的程式
#
# ![](https://drive.google.com/uc?export=download&id=1XkLM2bLptAP-tnz2Dt_EE8XG6LtjFwRm)
#
# ## 在設定動作時，我們需要以下：
#
# - 應用程式的名稱/在 OS 的路徑
# - 要被執行的 Python 檔案名稱

# %%
# !where python

# %% [markdown]
# 1. 動作選擇啓動程式
#
# 2. 請將 python.exe 的路徑注入至程式
#
# 3. 再將.py檔案的路徑輸入至新增引數
#
# ![](https://drive.google.com/uc?export=download&id=1a32YJQ8mUijwWPF9tsayKMDsceuH3iFu)
#
# 別忘了設定條件：
#
# ![](https://drive.google.com/uc?export=download&id=1IM-RbNRpMNqFmMJOT1Q1QveP-OR6UcVB)
#
# 設定完畢之後，建立好的工作應該會出現在工作清單，若要測試，可以點選一下執行：
#
# ![](https://drive.google.com/uc?export=download&id=1YyZd2ZV6sYwhDwANaCtcyfJo4aLWECmI)
