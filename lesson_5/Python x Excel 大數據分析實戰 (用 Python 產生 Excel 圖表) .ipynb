# %% [markdown]
# # 用 Python 產生 Excel 圖表
#
# 我們今天來解決一個自動化 Excel 時經常遇到的問題：透過程式化的方式自動產生 Excel 圖表
#
# 在完成之後，我們會利用所學打造一個股票即時走勢圖的功能
#
# 在嘗試自動化圖表之前，我們先來觀察一下要如何透過手動的方式產生圖表
#
# 透過 Python 產生即時走勢圖的實作方法有很多種，本課程將會使用 Excel 内建的圖表功能來實作走勢圖
#
# Excel 圖表的類型衆多，我們會使用 **開盤-高-低-收盤股價圖** 來繪製走勢圖：
#
# 1. 開啓 `TW2884.xlsx` 範例檔案
# 2. 接下來，請選擇工作表上 B 欄到 E 欄所有的資料，也就是玉山銀行一天的開-高-低-收四個時間序列
#
# ![](https://drive.google.com/uc?export=download&id=1Vd7lDwSCRpHG5-0JwEz3qwWfpRL1Dlwp)
#
# 3. 選擇好之後按下**插入 > 股票圖 > 開盤-高-低-收盤股價圖**
#
# ![](https://drive.google.com/uc?export=download&id=1XEkpufakOqFKHynuLpXENCcWOnaaUKng)
#
# 這樣就可以讓 Excel 幫我們把走勢圖產生出來了！
#
#
# 透過剛才的範例，我們注意到了，在繪製圖表前，最麻煩的事情是我們需要：
#
# 1. 先獲得繪製走勢圖的資料(開-高-低-收盤價)
# 2. 一筆筆交易日的資料，並且要把資料整理成以下格式：
# ![](https://drive.google.com/uc?export=download&id=1xWghyvrJQ5ZPjR4QN7Mz3_Zw5ujCVo4t)
#
# 幸好上述都可以透過 Python 自動化，我們先從資料的部分開始：

# %% [markdown]
# ## 透過 fugle API 截取即時走勢資料
#
# 我們會使用之前介紹的截取我們需要的資料
#
# 請先連至：[fugle API 文件](https://developer.fugle.tw/realtime/document#/Intraday/get_intraday_chart)
#
# 我們來看一下 `/intraday/chart` 這個 API

# %% [markdown]
# # 觀察一下回傳的結果
#
# ```json
# {
#   {'2019-06-28T01:01:00.000Z': {'close': 26.3,
#     'high': 26.3,
#     'low': 26.3,
#     'open': 26.3,
#     'unit': 426,
#     'volume': 426000},
#    '2019-06-28T01:02:00.000Z': {'close': 26.3,
#     'high': 26.3,
#     'low': 26.3,
#     'open': 26.3,
#     'unit': 47,
#     'volume': 47000}
#    }
# }
# ```
#
# 我們要的資料是被放在 data > chart 内，**每一個交易時段與相對應的開盤-高-低-收盤股價是以 key : value 的形式被封裝在字典内**

# %%
import requests

payload = {
    "symbolId": "2884",
    "apiToken": api_token
}

res = requests.get("https://api.fugle.tw/realtime/v0/intraday/chart", params=payload)

result = res.json()
result
# Out:
# {'apiVersion': '0.1.0',
#  'data': {'info': {'countryCode': 'TW',
#    'date': '2019-11-12',
#    'lastUpdatedAt': '2019-11-12T05:30:00.000Z',
#    'mode': 'twse-sem',
#    'symbolId': '2884',
#    'timeZone': 'Asia/Taipei'},
#   'chart': {'2019-11-12T01:01:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 793,
#     'volume': 793000},
#    '2019-11-12T01:02:00.000Z': {'close': 27.35,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 150,
#     'volume': 150000},
#    '2019-11-12T01:03:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.3,
#     'open': 27.35,
#     'unit': 250,
#     'volume': 250000},
#    '2019-11-12T01:04:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.4,
#     'open': 27.4,
#     'unit': 60,
#     'volume': 60000},
#    '2019-11-12T01:05:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.35,
#     'open': 27.4,
#     'unit': 213,
#     'volume': 213000},
#    '2019-11-12T01:06:00.000Z': {'close': 27.45,
#     'high': 27.45,
#     'low': 27.4,
#     'open': 27.4,
#     'unit': 152,
#     'volume': 152000},
#    '2019-11-12T01:07:00.000Z': {'close': 27.45,
#     'high': 27.45,
#     'low': 27.45,
#     'open': 27.45,
#     'unit': 10,
#     'volume': 10000},
#    '2019-11-12T01:08:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.35,
#     'open': 27.4,
#     'unit': 174,
#     'volume': 174000},
#    '2019-11-12T01:09:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.35,
#     'open': 27.4,
#     'unit': 23,
#     'volume': 23000},
#    '2019-11-12T01:10:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.4,
#     'open': 27.4,
#     'unit': 23,
#     'volume': 23000},
#    '2019-11-12T01:11:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.35,
#     'open': 27.4,
#     'unit': 8,
#     'volume': 8000},
#    '2019-11-12T01:12:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.4,
#     'open': 27.4,
#     'unit': 3,
#     'volume': 3000},
#    '2019-11-12T01:13:00.000Z': {'close': 27.35,
#     'high': 27.4,
#     'low': 27.35,
#     'open': 27.4,
#     'unit': 6,
#     'volume': 6000},
#    '2019-11-12T01:14:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.4,
#     'open': 27.4,
#     'unit': 13,
#     'volume': 13000},
#    '2019-11-12T01:15:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.35,
#     'open': 27.35,
#     'unit': 23,
#     'volume': 23000},
#    '2019-11-12T01:16:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.4,
#     'open': 27.4,
#     'unit': 12,
#     'volume': 12000},
#    '2019-11-12T01:17:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.4,
#     'open': 27.4,
#     'unit': 6,
#     'volume': 6000},
#    '2019-11-12T01:18:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.4,
#     'open': 27.4,
#     'unit': 38,
#     'volume': 38000},
#    '2019-11-12T01:19:00.000Z': {'close': 27.35,
#     'high': 27.4,
#     'low': 27.35,
#     'open': 27.4,
#     'unit': 30,
#     'volume': 30000},
#    '2019-11-12T01:20:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.4,
#     'open': 27.4,
#     'unit': 12,
#     'volume': 12000},
#    '2019-11-12T01:21:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.35,
#     'open': 27.4,
#     'unit': 62,
#     'volume': 62000},
#    '2019-11-12T01:22:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.4,
#     'open': 27.4,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T01:23:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.4,
#     'open': 27.4,
#     'unit': 4,
#     'volume': 4000},
#    '2019-11-12T01:24:00.000Z': {'close': 27.35,
#     'high': 27.4,
#     'low': 27.35,
#     'open': 27.4,
#     'unit': 155,
#     'volume': 155000},
#    '2019-11-12T01:25:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.35,
#     'open': 27.35,
#     'unit': 22,
#     'volume': 22000},
#    '2019-11-12T01:26:00.000Z': {'close': 27.35,
#     'high': 27.4,
#     'low': 27.35,
#     'open': 27.4,
#     'unit': 67,
#     'volume': 67000},
#    '2019-11-12T01:27:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.35,
#     'open': 27.35,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T01:28:00.000Z': {'close': 27.4,
#     'high': 27.4,
#     'low': 27.4,
#     'open': 27.4,
#     'unit': 4,
#     'volume': 4000},
#    '2019-11-12T01:29:00.000Z': {'close': 27.35,
#     'high': 27.35,
#     'low': 27.35,
#     'open': 27.35,
#     'unit': 144,
#     'volume': 144000},
#    '2019-11-12T01:30:00.000Z': {'close': 27.3,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.35,
#     'unit': 404,
#     'volume': 404000},
#    '2019-11-12T01:31:00.000Z': {'close': 27.35,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.35,
#     'unit': 15,
#     'volume': 15000},
#    '2019-11-12T01:32:00.000Z': {'close': 27.35,
#     'high': 27.35,
#     'low': 27.35,
#     'open': 27.35,
#     'unit': 9,
#     'volume': 9000},
#    '2019-11-12T01:33:00.000Z': {'close': 27.35,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 49,
#     'volume': 49000},
#    '2019-11-12T01:34:00.000Z': {'close': 27.3,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 16,
#     'volume': 16000},
#    '2019-11-12T01:35:00.000Z': {'close': 27.3,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 15,
#     'volume': 15000},
#    '2019-11-12T01:36:00.000Z': {'close': 27.35,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T01:37:00.000Z': {'close': 27.3,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.35,
#     'unit': 30,
#     'volume': 30000},
#    '2019-11-12T01:38:00.000Z': {'close': 27.35,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 27,
#     'volume': 27000},
#    '2019-11-12T01:39:00.000Z': {'close': 27.35,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 12,
#     'volume': 12000},
#    '2019-11-12T01:40:00.000Z': {'close': 27.3,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.35,
#     'unit': 46,
#     'volume': 46000},
#    '2019-11-12T01:41:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 16,
#     'volume': 16000},
#    '2019-11-12T01:42:00.000Z': {'close': 27.3,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.35,
#     'unit': 4,
#     'volume': 4000},
#    '2019-11-12T01:43:00.000Z': {'close': 27.3,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.35,
#     'unit': 16,
#     'volume': 16000},
#    '2019-11-12T01:44:00.000Z': {'close': 27.3,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.35,
#     'unit': 7,
#     'volume': 7000},
#    '2019-11-12T01:45:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 54,
#     'volume': 54000},
#    '2019-11-12T01:46:00.000Z': {'close': 27.3,
#     'high': 27.35,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 38,
#     'volume': 38000},
#    '2019-11-12T01:47:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 115,
#     'volume': 115000},
#    '2019-11-12T01:48:00.000Z': {'close': 27.25,
#     'high': 27.35,
#     'low': 27.25,
#     'open': 27.35,
#     'unit': 700,
#     'volume': 700000},
#    '2019-11-12T01:49:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 35,
#     'volume': 35000},
#    '2019-11-12T01:50:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 37,
#     'volume': 37000},
#    '2019-11-12T01:51:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 99,
#     'volume': 99000},
#    '2019-11-12T01:52:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 21,
#     'volume': 21000},
#    '2019-11-12T01:53:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 14,
#     'volume': 14000},
#    '2019-11-12T01:54:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 24,
#     'volume': 24000},
#    '2019-11-12T01:55:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 10,
#     'volume': 10000},
#    '2019-11-12T01:56:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 12,
#     'volume': 12000},
#    '2019-11-12T01:57:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 65,
#     'volume': 65000},
#    '2019-11-12T01:58:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 14,
#     'volume': 14000},
#    '2019-11-12T01:59:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 13,
#     'volume': 13000},
#    '2019-11-12T02:00:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 76,
#     'volume': 76000},
#    '2019-11-12T02:01:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 77,
#     'volume': 77000},
#    '2019-11-12T02:02:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 38,
#     'volume': 38000},
#    '2019-11-12T02:03:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 50,
#     'volume': 50000},
#    '2019-11-12T02:04:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 9,
#     'volume': 9000},
#    '2019-11-12T02:05:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 55,
#     'volume': 55000},
#    '2019-11-12T02:06:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 120,
#     'volume': 120000},
#    '2019-11-12T02:07:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 20,
#     'volume': 20000},
#    '2019-11-12T02:08:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 60,
#     'volume': 60000},
#    '2019-11-12T02:09:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 75,
#     'volume': 75000},
#    '2019-11-12T02:10:00.000Z': {'close': 27.2,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 811,
#     'volume': 811000},
#    '2019-11-12T02:11:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.2,
#     'unit': 291,
#     'volume': 291000},
#    '2019-11-12T02:12:00.000Z': {'close': 27.2,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.2,
#     'unit': 28,
#     'volume': 28000},
#    '2019-11-12T02:13:00.000Z': {'close': 27.2,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 21,
#     'volume': 21000},
#    '2019-11-12T02:14:00.000Z': {'close': 27.2,
#     'high': 27.2,
#     'low': 27.2,
#     'open': 27.2,
#     'unit': 37,
#     'volume': 37000},
#    '2019-11-12T02:15:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 42,
#     'volume': 42000},
#    '2019-11-12T02:16:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.2,
#     'unit': 7,
#     'volume': 7000},
#    '2019-11-12T02:17:00.000Z': {'close': 27.2,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 16,
#     'volume': 16000},
#    '2019-11-12T02:18:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 8,
#     'volume': 8000},
#    '2019-11-12T02:19:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 732,
#     'volume': 732000},
#    '2019-11-12T02:20:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 10,
#     'volume': 10000},
#    '2019-11-12T02:21:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T02:22:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 3,
#     'volume': 3000},
#    '2019-11-12T02:23:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 34,
#     'volume': 34000},
#    '2019-11-12T02:24:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T02:25:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 1,
#     'volume': 1000},
#    '2019-11-12T02:26:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 8,
#     'volume': 8000},
#    '2019-11-12T02:27:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 6,
#     'volume': 6000},
#    '2019-11-12T02:28:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 59,
#     'volume': 59000},
#    '2019-11-12T02:29:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 62,
#     'volume': 62000},
#    '2019-11-12T02:30:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 130,
#     'volume': 130000},
#    '2019-11-12T02:31:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 19,
#     'volume': 19000},
#    '2019-11-12T02:32:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 56,
#     'volume': 56000},
#    '2019-11-12T02:33:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 122,
#     'volume': 122000},
#    '2019-11-12T02:34:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 60,
#     'volume': 60000},
#    '2019-11-12T02:35:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 18,
#     'volume': 18000},
#    '2019-11-12T02:36:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T02:37:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 23,
#     'volume': 23000},
#    '2019-11-12T02:38:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 40,
#     'volume': 40000},
#    '2019-11-12T02:39:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 55,
#     'volume': 55000},
#    '2019-11-12T02:40:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 77,
#     'volume': 77000},
#    '2019-11-12T02:41:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 33,
#     'volume': 33000},
#    '2019-11-12T02:42:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 13,
#     'volume': 13000},
#    '2019-11-12T02:43:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 7,
#     'volume': 7000},
#    '2019-11-12T02:44:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.2,
#     'open': 27.3,
#     'unit': 180,
#     'volume': 180000},
#    '2019-11-12T02:45:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.2,
#     'unit': 87,
#     'volume': 87000},
#    '2019-11-12T02:46:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 9,
#     'volume': 9000},
#    '2019-11-12T02:47:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.2,
#     'unit': 38,
#     'volume': 38000},
#    '2019-11-12T02:48:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 13,
#     'volume': 13000},
#    '2019-11-12T02:49:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 93,
#     'volume': 93000},
#    '2019-11-12T02:50:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 93,
#     'volume': 93000},
#    '2019-11-12T02:51:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 148,
#     'volume': 148000},
#    '2019-11-12T02:52:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 15,
#     'volume': 15000},
#    '2019-11-12T02:53:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 13,
#     'volume': 13000},
#    '2019-11-12T02:54:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 12,
#     'volume': 12000},
#    '2019-11-12T02:56:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 15,
#     'volume': 15000},
#    '2019-11-12T02:57:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 13,
#     'volume': 13000},
#    '2019-11-12T02:58:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 44,
#     'volume': 44000},
#    '2019-11-12T02:59:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 4,
#     'volume': 4000},
#    '2019-11-12T03:00:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 8,
#     'volume': 8000},
#    '2019-11-12T03:01:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 6,
#     'volume': 6000},
#    '2019-11-12T03:02:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 7,
#     'volume': 7000},
#    '2019-11-12T03:03:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 33,
#     'volume': 33000},
#    '2019-11-12T03:04:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 20,
#     'volume': 20000},
#    '2019-11-12T03:05:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 106,
#     'volume': 106000},
#    '2019-11-12T03:06:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 43,
#     'volume': 43000},
#    '2019-11-12T03:07:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 3,
#     'volume': 3000},
#    '2019-11-12T03:08:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 29,
#     'volume': 29000},
#    '2019-11-12T03:09:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 7,
#     'volume': 7000},
#    '2019-11-12T03:10:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 4,
#     'volume': 4000},
#    '2019-11-12T03:11:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 11,
#     'volume': 11000},
#    '2019-11-12T03:12:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 9,
#     'volume': 9000},
#    '2019-11-12T03:13:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 51,
#     'volume': 51000},
#    '2019-11-12T03:14:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T03:15:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 2,
#     'volume': 2000},
#    '2019-11-12T03:16:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 7,
#     'volume': 7000},
#    '2019-11-12T03:17:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 2,
#     'volume': 2000},
#    '2019-11-12T03:18:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 34,
#     'volume': 34000},
#    '2019-11-12T03:19:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 41,
#     'volume': 41000},
#    '2019-11-12T03:20:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 35,
#     'volume': 35000},
#    '2019-11-12T03:21:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 13,
#     'volume': 13000},
#    '2019-11-12T03:22:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 6,
#     'volume': 6000},
#    '2019-11-12T03:23:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 40,
#     'volume': 40000},
#    '2019-11-12T03:24:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 39,
#     'volume': 39000},
#    '2019-11-12T03:25:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 162,
#     'volume': 162000},
#    '2019-11-12T03:26:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T03:27:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 13,
#     'volume': 13000},
#    '2019-11-12T03:28:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 85,
#     'volume': 85000},
#    '2019-11-12T03:29:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 91,
#     'volume': 91000},
#    '2019-11-12T03:30:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 36,
#     'volume': 36000},
#    '2019-11-12T03:31:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 41,
#     'volume': 41000},
#    '2019-11-12T03:32:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 22,
#     'volume': 22000},
#    '2019-11-12T03:33:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 48,
#     'volume': 48000},
#    '2019-11-12T03:34:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 51,
#     'volume': 51000},
#    '2019-11-12T03:35:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 2,
#     'volume': 2000},
#    '2019-11-12T03:36:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 12,
#     'volume': 12000},
#    '2019-11-12T03:37:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 2,
#     'volume': 2000},
#    '2019-11-12T03:38:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 44,
#     'volume': 44000},
#    '2019-11-12T03:40:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 46,
#     'volume': 46000},
#    '2019-11-12T03:41:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 23,
#     'volume': 23000},
#    '2019-11-12T03:42:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 53,
#     'volume': 53000},
#    '2019-11-12T03:43:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 59,
#     'volume': 59000},
#    '2019-11-12T03:44:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 18,
#     'volume': 18000},
#    '2019-11-12T03:45:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 33,
#     'volume': 33000},
#    '2019-11-12T03:46:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 20,
#     'volume': 20000},
#    '2019-11-12T03:47:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 60,
#     'volume': 60000},
#    '2019-11-12T03:48:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 42,
#     'volume': 42000},
#    '2019-11-12T03:49:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 9,
#     'volume': 9000},
#    '2019-11-12T03:50:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 13,
#     'volume': 13000},
#    '2019-11-12T03:51:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 198,
#     'volume': 198000},
#    '2019-11-12T03:52:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 25,
#     'volume': 25000},
#    '2019-11-12T03:53:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 61,
#     'volume': 61000},
#    '2019-11-12T03:54:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 18,
#     'volume': 18000},
#    '2019-11-12T03:55:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 32,
#     'volume': 32000},
#    '2019-11-12T03:56:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 4,
#     'volume': 4000},
#    '2019-11-12T03:57:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T03:58:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 46,
#     'volume': 46000},
#    '2019-11-12T03:59:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 12,
#     'volume': 12000},
#    '2019-11-12T04:00:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 7,
#     'volume': 7000},
#    '2019-11-12T04:01:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 3,
#     'volume': 3000},
#    '2019-11-12T04:02:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 15,
#     'volume': 15000},
#    '2019-11-12T04:03:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 31,
#     'volume': 31000},
#    '2019-11-12T04:04:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 8,
#     'volume': 8000},
#    '2019-11-12T04:05:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T04:06:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 4,
#     'volume': 4000},
#    '2019-11-12T04:07:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 38,
#     'volume': 38000},
#    '2019-11-12T04:08:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 47,
#     'volume': 47000},
#    '2019-11-12T04:09:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 103,
#     'volume': 103000},
#    '2019-11-12T04:10:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 6,
#     'volume': 6000},
#    '2019-11-12T04:11:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 21,
#     'volume': 21000},
#    '2019-11-12T04:12:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 3,
#     'volume': 3000},
#    '2019-11-12T04:13:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 49,
#     'volume': 49000},
#    '2019-11-12T04:14:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 9,
#     'volume': 9000},
#    '2019-11-12T04:15:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T04:16:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 3,
#     'volume': 3000},
#    '2019-11-12T04:17:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 8,
#     'volume': 8000},
#    '2019-11-12T04:18:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 40,
#     'volume': 40000},
#    '2019-11-12T04:19:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 8,
#     'volume': 8000},
#    '2019-11-12T04:20:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 21,
#     'volume': 21000},
#    '2019-11-12T04:21:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 60,
#     'volume': 60000},
#    '2019-11-12T04:22:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 2,
#     'volume': 2000},
#    '2019-11-12T04:23:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 93,
#     'volume': 93000},
#    '2019-11-12T04:24:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 45,
#     'volume': 45000},
#    '2019-11-12T04:25:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 8,
#     'volume': 8000},
#    '2019-11-12T04:26:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 129,
#     'volume': 129000},
#    '2019-11-12T04:27:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 120,
#     'volume': 120000},
#    '2019-11-12T04:28:00.000Z': {'close': 27.2,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 317,
#     'volume': 317000},
#    '2019-11-12T04:29:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.2,
#     'unit': 10,
#     'volume': 10000},
#    '2019-11-12T04:30:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 59,
#     'volume': 59000},
#    '2019-11-12T04:31:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.2,
#     'unit': 15,
#     'volume': 15000},
#    '2019-11-12T04:32:00.000Z': {'close': 27.2,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 22,
#     'volume': 22000},
#    '2019-11-12T04:33:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 175,
#     'volume': 175000},
#    '2019-11-12T04:34:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 16,
#     'volume': 16000},
#    '2019-11-12T04:35:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 24,
#     'volume': 24000},
#    '2019-11-12T04:36:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 48,
#     'volume': 48000},
#    '2019-11-12T04:37:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 53,
#     'volume': 53000},
#    '2019-11-12T04:38:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.2,
#     'open': 27.25,
#     'unit': 28,
#     'volume': 28000},
#    '2019-11-12T04:39:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 139,
#     'volume': 139000},
#    '2019-11-12T04:40:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 26,
#     'volume': 26000},
#    '2019-11-12T04:41:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 3,
#     'volume': 3000},
#    '2019-11-12T04:42:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 8,
#     'volume': 8000},
#    '2019-11-12T04:43:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 8,
#     'volume': 8000},
#    '2019-11-12T04:44:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 8,
#     'volume': 8000},
#    '2019-11-12T04:45:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 7,
#     'volume': 7000},
#    '2019-11-12T04:46:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T04:47:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 54,
#     'volume': 54000},
#    '2019-11-12T04:48:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 40,
#     'volume': 40000},
#    '2019-11-12T04:49:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 12,
#     'volume': 12000},
#    '2019-11-12T04:50:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 3,
#     'volume': 3000},
#    '2019-11-12T04:51:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T04:52:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 59,
#     'volume': 59000},
#    '2019-11-12T04:53:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 33,
#     'volume': 33000},
#    '2019-11-12T04:54:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 40,
#     'volume': 40000},
#    '2019-11-12T04:55:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 41,
#     'volume': 41000},
#    '2019-11-12T04:56:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 5,
#     'volume': 5000},
#    '2019-11-12T04:57:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 29,
#     'volume': 29000},
#    '2019-11-12T04:58:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.3,
#     'open': 27.3,
#     'unit': 7,
#     'volume': 7000},
#    '2019-11-12T04:59:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 44,
#     'volume': 44000},
#    '2019-11-12T05:00:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 12,
#     'volume': 12000},
#    '2019-11-12T05:01:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 31,
#     'volume': 31000},
#    '2019-11-12T05:02:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 60,
#     'volume': 60000},
#    '2019-11-12T05:03:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 68,
#     'volume': 68000},
#    '2019-11-12T05:04:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 48,
#     'volume': 48000},
#    '2019-11-12T05:05:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 160,
#     'volume': 160000},
#    '2019-11-12T05:06:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 24,
#     'volume': 24000},
#    '2019-11-12T05:07:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 56,
#     'volume': 56000},
#    '2019-11-12T05:08:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 39,
#     'volume': 39000},
#    '2019-11-12T05:09:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 72,
#     'volume': 72000},
#    '2019-11-12T05:10:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 42,
#     'volume': 42000},
#    '2019-11-12T05:11:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 24,
#     'volume': 24000},
#    '2019-11-12T05:12:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 72,
#     'volume': 72000},
#    '2019-11-12T05:13:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 43,
#     'volume': 43000},
#    '2019-11-12T05:14:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 83,
#     'volume': 83000},
#    '2019-11-12T05:15:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 19,
#     'volume': 19000},
#    '2019-11-12T05:16:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 126,
#     'volume': 126000},
#    '2019-11-12T05:17:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 63,
#     'volume': 63000},
#    '2019-11-12T05:18:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 38,
#     'volume': 38000},
#    '2019-11-12T05:19:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.3,
#     'unit': 45,
#     'volume': 45000},
#    '2019-11-12T05:20:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 405,
#     'volume': 405000},
#    '2019-11-12T05:21:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 62,
#     'volume': 62000},
#    '2019-11-12T05:22:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 22,
#     'volume': 22000},
#    '2019-11-12T05:23:00.000Z': {'close': 27.25,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 112,
#     'volume': 112000},
#    '2019-11-12T05:24:00.000Z': {'close': 27.3,
#     'high': 27.3,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 31,
#     'volume': 31000},
#    '2019-11-12T05:25:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 18,
#     'volume': 18000},
#    '2019-11-12T05:30:00.000Z': {'close': 27.25,
#     'high': 27.25,
#     'low': 27.25,
#     'open': 27.25,
#     'unit': 1588,
#     'volume': 1588000}}}}

# %% [markdown]
# 若要截取某一個時間點的開高低收資料，我們需要輸入時間戳：
#
# ```python
# result["data"]["chart"]['2019-11-11T01:03:00.000Z']
# ```
#
# 才能將資料從該字典中提取出來：
#
# ```json
# {'close': 27.45,
#     'high': 27.5,
#     'low': 27.4,
#     'open': 27.5,
#     'unit': 202,
#     'volume': 202000}
# ```

# %% [markdown]
# 再回頭看看我們期望的 Excel 工作表格式：
#
# ![](https://drive.google.com/uc?export=download&id=1xWghyvrJQ5ZPjR4QN7Mz3_Zw5ujCVo4t)
#
#
# ## 回憶一下第一堂課的一個口號
#
# 要用 Python 與 xlwings 一次性的將多筆資料寫入一個 Excel 的範圍，就**必須將寫入的資料放入大小與儲存格範圍一樣的二維串列内**
#
# 現在我們需要把剛才從 fugle api 截取到的**資料轉成二維陣列**，才有可能將其**批次的寫入 Excel 工作表**：
#
#
# ```python
# [
#     ['2019-06-28T01:01:00.000Z', '26.3', '26.3', '26.3', '26.3','426', '426000'],
#     ['2019-06-28T01:02:00.000Z', '26.3', '26.3', '26.3', '26.3', '47', '47000'],
#     ['2019-06-28T01:03:00.000Z', '26.3', '26.35', '26.3', '26.35', '88', '88000']
# ]
# ```

# %% [markdown]
# 我們先將 fugle API 回傳給我們的 JSON 内，所有的 key，也就是時間戳提取出來：
#
# ```python
# result["data"]["chart"].keys()
# ```
#
# 結果會回傳：
#
# ```python
# dict_keys(['2019-11-11T01:01:00.000Z', '2019-11-11T01:02:00.000Z', '2019-11-11T01:03:00.000Z', '2019-11-11T01:04:00.000Z', '2019-11-11T01:05:00.000Z', '2019-11-11T01:06:00.000Z', '2019-11-11T01:07:00.000Z', '2019-11-11T01:08:00.000Z', '2019-11-11T01:09:00.000Z', ...
# ```

# %%
result["data"]["chart"].keys()
# Out:
# dict_keys(['2019-11-11T01:01:00.000Z', '2019-11-11T01:02:00.000Z', '2019-11-11T01:03:00.000Z', '2019-11-11T01:04:00.000Z', '2019-11-11T01:05:00.000Z', '2019-11-11T01:06:00.000Z', '2019-11-11T01:07:00.000Z', '2019-11-11T01:08:00.000Z', '2019-11-11T01:09:00.000Z', '2019-11-11T01:10:00.000Z', '2019-11-11T01:11:00.000Z', '2019-11-11T01:12:00.000Z', '2019-11-11T01:13:00.000Z', '2019-11-11T01:14:00.000Z', '2019-11-11T01:15:00.000Z', '2019-11-11T01:16:00.000Z', '2019-11-11T01:17:00.000Z', '2019-11-11T01:18:00.000Z', '2019-11-11T01:19:00.000Z', '2019-11-11T01:20:00.000Z', '2019-11-11T01:21:00.000Z', '2019-11-11T01:22:00.000Z', '2019-11-11T01:23:00.000Z', '2019-11-11T01:24:00.000Z', '2019-11-11T01:25:00.000Z', '2019-11-11T01:26:00.000Z', '2019-11-11T01:27:00.000Z', '2019-11-11T01:28:00.000Z', '2019-11-11T01:29:00.000Z', '2019-11-11T01:30:00.000Z', '2019-11-11T01:31:00.000Z', '2019-11-11T01:32:00.000Z', '2019-11-11T01:33:00.000Z', '2019-11-11T01:34:00.000Z', '2019-11-11T01:35:00.000Z', '2019-11-11T01:36:00.000Z', '2019-11-11T01:37:00.000Z', '2019-11-11T01:38:00.000Z', '2019-11-11T01:39:00.000Z', '2019-11-11T01:40:00.000Z', '2019-11-11T01:41:00.000Z', '2019-11-11T01:42:00.000Z', '2019-11-11T01:43:00.000Z', '2019-11-11T01:44:00.000Z', '2019-11-11T01:45:00.000Z', '2019-11-11T01:46:00.000Z', '2019-11-11T01:47:00.000Z', '2019-11-11T01:48:00.000Z', '2019-11-11T01:49:00.000Z', '2019-11-11T01:50:00.000Z', '2019-11-11T01:51:00.000Z', '2019-11-11T01:52:00.000Z', '2019-11-11T01:53:00.000Z', '2019-11-11T01:54:00.000Z', '2019-11-11T01:55:00.000Z', '2019-11-11T01:56:00.000Z', '2019-11-11T01:57:00.000Z', '2019-11-11T01:58:00.000Z', '2019-11-11T01:59:00.000Z', '2019-11-11T02:00:00.000Z', '2019-11-11T02:01:00.000Z', '2019-11-11T02:02:00.000Z', '2019-11-11T02:03:00.000Z', '2019-11-11T02:04:00.000Z', '2019-11-11T02:05:00.000Z', '2019-11-11T02:06:00.000Z', '2019-11-11T02:07:00.000Z', '2019-11-11T02:08:00.000Z', '2019-11-11T02:09:00.000Z', '2019-11-11T02:10:00.000Z', '2019-11-11T02:11:00.000Z', '2019-11-11T02:12:00.000Z', '2019-11-11T02:13:00.000Z', '2019-11-11T02:14:00.000Z', '2019-11-11T02:15:00.000Z', '2019-11-11T02:16:00.000Z', '2019-11-11T02:17:00.000Z', '2019-11-11T02:18:00.000Z', '2019-11-11T02:19:00.000Z', '2019-11-11T02:20:00.000Z', '2019-11-11T02:21:00.000Z', '2019-11-11T02:22:00.000Z', '2019-11-11T02:23:00.000Z', '2019-11-11T02:24:00.000Z', '2019-11-11T02:25:00.000Z', '2019-11-11T02:26:00.000Z', '2019-11-11T02:27:00.000Z', '2019-11-11T02:28:00.000Z', '2019-11-11T02:29:00.000Z', '2019-11-11T02:30:00.000Z', '2019-11-11T02:31:00.000Z', '2019-11-11T02:32:00.000Z', '2019-11-11T02:33:00.000Z', '2019-11-11T02:34:00.000Z', '2019-11-11T02:35:00.000Z', '2019-11-11T02:36:00.000Z', '2019-11-11T02:37:00.000Z', '2019-11-11T02:38:00.000Z', '2019-11-11T02:39:00.000Z', '2019-11-11T02:40:00.000Z', '2019-11-11T02:41:00.000Z', '2019-11-11T02:42:00.000Z', '2019-11-11T02:43:00.000Z', '2019-11-11T02:44:00.000Z', '2019-11-11T02:45:00.000Z', '2019-11-11T02:46:00.000Z', '2019-11-11T02:47:00.000Z', '2019-11-11T02:48:00.000Z', '2019-11-11T02:49:00.000Z', '2019-11-11T02:50:00.000Z', '2019-11-11T02:51:00.000Z', '2019-11-11T02:52:00.000Z', '2019-11-11T02:53:00.000Z', '2019-11-11T02:54:00.000Z', '2019-11-11T02:55:00.000Z', '2019-11-11T02:56:00.000Z', '2019-11-11T02:57:00.000Z', '2019-11-11T02:58:00.000Z', '2019-11-11T02:59:00.000Z', '2019-11-11T03:00:00.000Z', '2019-11-11T03:01:00.000Z', '2019-11-11T03:02:00.000Z', '2019-11-11T03:03:00.000Z', '2019-11-11T03:04:00.000Z', '2019-11-11T03:05:00.000Z', '2019-11-11T03:06:00.000Z', '2019-11-11T03:07:00.000Z', '2019-11-11T03:08:00.000Z', '2019-11-11T03:09:00.000Z', '2019-11-11T03:10:00.000Z', '2019-11-11T03:11:00.000Z', '2019-11-11T03:12:00.000Z', '2019-11-11T03:13:00.000Z', '2019-11-11T03:14:00.000Z', '2019-11-11T03:15:00.000Z', '2019-11-11T03:16:00.000Z', '2019-11-11T03:17:00.000Z', '2019-11-11T03:18:00.000Z', '2019-11-11T03:19:00.000Z', '2019-11-11T03:20:00.000Z', '2019-11-11T03:21:00.000Z', '2019-11-11T03:22:00.000Z', '2019-11-11T0 ...

# %%
time_idx = result["data"]["chart"].keys()

for idx in time_idx:
    data = result["data"]["chart"][idx]
    print(data)
# Out:
# {'close': 27.6, 'high': 27.6, 'low': 27.55, 'open': 27.6, 'unit': 501, 'volume': 501000}
# {'close': 27.5, 'high': 27.55, 'low': 27.5, 'open': 27.55, 'unit': 118, 'volume': 118000}
# {'close': 27.55, 'high': 27.6, 'low': 27.5, 'open': 27.5, 'unit': 83, 'volume': 83000}
# {'close': 27.45, 'high': 27.5, 'low': 27.45, 'open': 27.5, 'unit': 449, 'volume': 449000}
# {'close': 27.45, 'high': 27.5, 'low': 27.4, 'open': 27.5, 'unit': 202, 'volume': 202000}
# {'close': 27.4, 'high': 27.45, 'low': 27.4, 'open': 27.4, 'unit': 57, 'volume': 57000}
# {'close': 27.4, 'high': 27.45, 'low': 27.4, 'open': 27.4, 'unit': 37, 'volume': 37000}
# {'close': 27.4, 'high': 27.45, 'low': 27.4, 'open': 27.4, 'unit': 74, 'volume': 74000}
# {'close': 27.35, 'high': 27.4, 'low': 27.35, 'open': 27.4, 'unit': 371, 'volume': 371000}
# {'close': 27.35, 'high': 27.35, 'low': 27.35, 'open': 27.35, 'unit': 142, 'volume': 142000}
# {'close': 27.35, 'high': 27.4, 'low': 27.3, 'open': 27.35, 'unit': 452, 'volume': 452000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 78, 'volume': 78000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 122, 'volume': 122000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 99, 'volume': 99000}
# {'close': 27.4, 'high': 27.4, 'low': 27.3, 'open': 27.3, 'unit': 659, 'volume': 659000}
# {'close': 27.4, 'high': 27.4, 'low': 27.35, 'open': 27.35, 'unit': 17, 'volume': 17000}
# {'close': 27.35, 'high': 27.4, 'low': 27.35, 'open': 27.4, 'unit': 239, 'volume': 239000}
# {'close': 27.4, 'high': 27.4, 'low': 27.35, 'open': 27.4, 'unit': 43, 'volume': 43000}
# {'close': 27.4, 'high': 27.4, 'low': 27.35, 'open': 27.4, 'unit': 84, 'volume': 84000}
# {'close': 27.35, 'high': 27.4, 'low': 27.35, 'open': 27.4, 'unit': 48, 'volume': 48000}
# {'close': 27.4, 'high': 27.4, 'low': 27.35, 'open': 27.35, 'unit': 24, 'volume': 24000}
# {'close': 27.4, 'high': 27.4, 'low': 27.35, 'open': 27.4, 'unit': 45, 'volume': 45000}
# {'close': 27.35, 'high': 27.4, 'low': 27.35, 'open': 27.35, 'unit': 116, 'volume': 116000}
# {'close': 27.35, 'high': 27.4, 'low': 27.35, 'open': 27.35, 'unit': 57, 'volume': 57000}
# {'close': 27.35, 'high': 27.4, 'low': 27.35, 'open': 27.35, 'unit': 86, 'volume': 86000}
# {'close': 27.4, 'high': 27.4, 'low': 27.35, 'open': 27.35, 'unit': 77, 'volume': 77000}
# {'close': 27.35, 'high': 27.35, 'low': 27.35, 'open': 27.35, 'unit': 62, 'volume': 62000}
# {'close': 27.35, 'high': 27.35, 'low': 27.35, 'open': 27.35, 'unit': 529, 'volume': 529000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 241, 'volume': 241000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 163, 'volume': 163000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 120, 'volume': 120000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 102, 'volume': 102000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 320, 'volume': 320000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 127, 'volume': 127000}
# {'close': 27.35, 'high': 27.35, 'low': 27.35, 'open': 27.35, 'unit': 24, 'volume': 24000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 22, 'volume': 22000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 17, 'volume': 17000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 12, 'volume': 12000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 8, 'volume': 8000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 15, 'volume': 15000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 49, 'volume': 49000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 260, 'volume': 260000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 79, 'volume': 79000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 105, 'volume': 105000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 124, 'volume': 124000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 77, 'volume': 77000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 70, 'volume': 70000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 140, 'volume': 140000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 65, 'volume': 65000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 76, 'volume': 76000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 37, 'volume': 37000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 68, 'volume': 68000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 129, 'volume': 129000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 139, 'volume': 139000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 150, 'volume': 150000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 101, 'volume': 101000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 521, 'volume': 521000}
# {'close': 27.25, 'high': 27.35, 'low': 27.25, 'open': 27.3, 'unit': 646, 'volume': 646000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 44, 'volume': 44000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 70, 'volume': 70000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 22, 'volume': 22000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 36, 'volume': 36000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 128, 'volume': 128000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 654, 'volume': 654000}
# {'close': 27.25, 'high': 27.25, 'low': 27.2, 'open': 27.25, 'unit': 236, 'volume': 236000}
# {'close': 27.25, 'high': 27.25, 'low': 27.2, 'open': 27.2, 'unit': 245, 'volume': 245000}
# {'close': 27.3, 'high': 27.3, 'low': 27.2, 'open': 27.2, 'unit': 212, 'volume': 212000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 68, 'volume': 68000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 10, 'volume': 10000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 72, 'volume': 72000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 42, 'volume': 42000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 85, 'volume': 85000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 232, 'volume': 232000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 57, 'volume': 57000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 82, 'volume': 82000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 14, 'volume': 14000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 106, 'volume': 106000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 16, 'volume': 16000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 3, 'volume': 3000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 632, 'volume': 632000}
# {'close': 27.35, 'high': 27.35, 'low': 27.25, 'open': 27.35, 'unit': 137, 'volume': 137000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 10, 'volume': 10000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 5, 'volume': 5000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 78, 'volume': 78000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 59, 'volume': 59000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 32, 'volume': 32000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 31, 'volume': 31000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 34, 'volume': 34000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 18, 'volume': 18000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 12, 'volume': 12000}
# {'close': 27.35, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 31, 'volume': 31000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.35, 'unit': 17, 'volume': 17000}
# {'close': 27.3, 'high': 27.35, 'low': 27.3, 'open': 27.3, 'unit': 48, 'volume': 48000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 8, 'volume': 8000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 154, 'volume': 154000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 107, 'volume': 107000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 33, 'volume': 33000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 16, 'volume': 16000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 9, 'volume': 9000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 14, 'volume': 14000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 16, 'volume': 16000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 6, 'volume': 6000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 10, 'volume': 10000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 6, 'volume': 6000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 34, 'volume': 34000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 14, 'volume': 14000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 3, 'volume': 3000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 9, 'volume': 9000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 6, 'volume': 6000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 37, 'volume': 37000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 121, 'volume': 121000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 169, 'volume': 169000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 25, 'volume': 25000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 106, 'volume': 106000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 11, 'volume': 11000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 79, 'volume': 79000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 22, 'volume': 22000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 10, 'volume': 10000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 38, 'volume': 38000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 69, 'volume': 69000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 66, 'volume': 66000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 15, 'volume': 15000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 7, 'volume': 7000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 16, 'volume': 16000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 3, 'volume': 3000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 46, 'volume': 46000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 9, 'volume': 9000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 32, 'volume': 32000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 46, 'volume': 46000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 91, 'volume': 91000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 97, 'volume': 97000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 47, 'volume': 47000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 24, 'volume': 24000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 23, 'volume': 23000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 18, 'volume': 18000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 16, 'volume': 16000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 12, 'volume': 12000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 9, 'volume': 9000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 35, 'volume': 35000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 35, 'volume': 35000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 75, 'volume': 75000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 14, 'volume': 14000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 18, 'volume': 18000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 54, 'volume': 54000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 34, 'volume': 34000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 7, 'volume': 7000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 30, 'volume': 30000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 18, 'volume': 18000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 8, 'volume': 8000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 49, 'volume': 49000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 22, 'volume': 22000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 17, 'volume': 17000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 12, 'volume': 12000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 26, 'volume': 26000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 14, 'volume': 14000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 17, 'volume': 17000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 8, 'volume': 8000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 49, 'volume': 49000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 223, 'volume': 223000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 47, 'volume': 47000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 88, 'volume': 88000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 15, 'volume': 15000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 25, 'volume': 25000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 6, 'volume': 6000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 8, 'volume': 8000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 8, 'volume': 8000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 19, 'volume': 19000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 4, 'volume': 4000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 166, 'volume': 166000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 16, 'volume': 16000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 2, 'volume': 2000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 25, 'volume': 25000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 7, 'volume': 7000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 226, 'volume': 226000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 9, 'volume': 9000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 42, 'volume': 42000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 2, 'volume': 2000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 5, 'volume': 5000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 3, 'volume': 3000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 13, 'volume': 13000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 41, 'volume': 41000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 22, 'volume': 22000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 50, 'volume': 50000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 80, 'volume': 80000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 4, 'volume': 4000}
# {'close': 27.3, 'high': 27.3, 'low': 27.3, 'open': 27.3, 'unit': 6, 'volume': 6000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 13, 'volume': 13000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 9, 'volume': 9000}
# {'close': 27.25, 'high': 27.25, 'low': 27.25, 'open': 27.25, 'unit': 20, 'volume': 20000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 21, 'volume': 21000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 59, 'volume': 59000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 25, 'volume': 25000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.25, 'unit': 105, 'volume': 105000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 64, 'volume': 64000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 54, 'volume': 54000}
# {'close': 27.3, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 40, 'volume': 40000}
# {'close': 27.25, 'high': 27.3, 'low': 27.25, 'open': 27.3, 'unit': 50, 'volume': 50000}

# %% [markdown]
# 接下來我們就將資料放入一個二維陣列中：
#
# ```python
# price_open = []
# price_high = []
# price_low = []
# price_close = []
# unit = []
# volume = []
#
# # 截取所有的時間戳
# time_idx = result["data"]["chart"].keys()
#
# # 將每一個時間點的六筆資料分別放入不同的串列内
# for idx in time_idx:
#     data = result["data"]["chart"][idx]
#     price_open.append(data["open"])
#     price_high.append(data["high"])
#     price_low.append(data["low"])
#     price_close.append(data["close"])
#     unit.append(data["unit"])
#     volume.append(data["volume"])
#
# # 最後再將這六個串列放入一個串列内
# chart_data = [list(time_idx), price_open,price_high,price_low,price_close,unit,volume]
# ```

# %%
price_open = []
price_high = []
price_low = []
price_close = []
unit = []
volume = []

# 截取所有的時間戳
time_idx = result["data"]["chart"].keys()

# 將每一個時間點的六筆資料分別放入不同的串列内
for idx in time_idx:
    data = result["data"]["chart"][idx]
    price_open.append(data["open"])
    price_high.append(data["high"])
    price_low.append(data["low"])
    price_close.append(data["close"])
    unit.append(data["unit"])
    volume.append(data["volume"])

# 最後再將這六個串列放入一個串列内
chart_data = [list(time_idx), price_open,price_high,price_low,price_close,unit,volume]
chart_data
# Out:
# [['2019-11-12T01:01:00.000Z',
#   '2019-11-12T01:02:00.000Z',
#   '2019-11-12T01:03:00.000Z',
#   '2019-11-12T01:04:00.000Z',
#   '2019-11-12T01:05:00.000Z',
#   '2019-11-12T01:06:00.000Z',
#   '2019-11-12T01:07:00.000Z',
#   '2019-11-12T01:08:00.000Z',
#   '2019-11-12T01:09:00.000Z',
#   '2019-11-12T01:10:00.000Z',
#   '2019-11-12T01:11:00.000Z',
#   '2019-11-12T01:12:00.000Z',
#   '2019-11-12T01:13:00.000Z',
#   '2019-11-12T01:14:00.000Z',
#   '2019-11-12T01:15:00.000Z',
#   '2019-11-12T01:16:00.000Z',
#   '2019-11-12T01:17:00.000Z',
#   '2019-11-12T01:18:00.000Z',
#   '2019-11-12T01:19:00.000Z',
#   '2019-11-12T01:20:00.000Z',
#   '2019-11-12T01:21:00.000Z',
#   '2019-11-12T01:22:00.000Z',
#   '2019-11-12T01:23:00.000Z',
#   '2019-11-12T01:24:00.000Z',
#   '2019-11-12T01:25:00.000Z',
#   '2019-11-12T01:26:00.000Z',
#   '2019-11-12T01:27:00.000Z',
#   '2019-11-12T01:28:00.000Z',
#   '2019-11-12T01:29:00.000Z',
#   '2019-11-12T01:30:00.000Z',
#   '2019-11-12T01:31:00.000Z',
#   '2019-11-12T01:32:00.000Z',
#   '2019-11-12T01:33:00.000Z',
#   '2019-11-12T01:34:00.000Z',
#   '2019-11-12T01:35:00.000Z',
#   '2019-11-12T01:36:00.000Z',
#   '2019-11-12T01:37:00.000Z',
#   '2019-11-12T01:38:00.000Z',
#   '2019-11-12T01:39:00.000Z',
#   '2019-11-12T01:40:00.000Z',
#   '2019-11-12T01:41:00.000Z',
#   '2019-11-12T01:42:00.000Z',
#   '2019-11-12T01:43:00.000Z',
#   '2019-11-12T01:44:00.000Z',
#   '2019-11-12T01:45:00.000Z',
#   '2019-11-12T01:46:00.000Z',
#   '2019-11-12T01:47:00.000Z',
#   '2019-11-12T01:48:00.000Z',
#   '2019-11-12T01:49:00.000Z',
#   '2019-11-12T01:50:00.000Z',
#   '2019-11-12T01:51:00.000Z',
#   '2019-11-12T01:52:00.000Z',
#   '2019-11-12T01:53:00.000Z',
#   '2019-11-12T01:54:00.000Z',
#   '2019-11-12T01:55:00.000Z',
#   '2019-11-12T01:56:00.000Z',
#   '2019-11-12T01:57:00.000Z',
#   '2019-11-12T01:58:00.000Z',
#   '2019-11-12T01:59:00.000Z',
#   '2019-11-12T02:00:00.000Z',
#   '2019-11-12T02:01:00.000Z',
#   '2019-11-12T02:02:00.000Z',
#   '2019-11-12T02:03:00.000Z',
#   '2019-11-12T02:04:00.000Z',
#   '2019-11-12T02:05:00.000Z',
#   '2019-11-12T02:06:00.000Z',
#   '2019-11-12T02:07:00.000Z',
#   '2019-11-12T02:08:00.000Z',
#   '2019-11-12T02:09:00.000Z',
#   '2019-11-12T02:10:00.000Z',
#   '2019-11-12T02:11:00.000Z',
#   '2019-11-12T02:12:00.000Z',
#   '2019-11-12T02:13:00.000Z',
#   '2019-11-12T02:14:00.000Z',
#   '2019-11-12T02:15:00.000Z',
#   '2019-11-12T02:16:00.000Z',
#   '2019-11-12T02:17:00.000Z',
#   '2019-11-12T02:18:00.000Z',
#   '2019-11-12T02:19:00.000Z',
#   '2019-11-12T02:20:00.000Z',
#   '2019-11-12T02:21:00.000Z',
#   '2019-11-12T02:22:00.000Z',
#   '2019-11-12T02:23:00.000Z',
#   '2019-11-12T02:24:00.000Z',
#   '2019-11-12T02:25:00.000Z',
#   '2019-11-12T02:26:00.000Z',
#   '2019-11-12T02:27:00.000Z',
#   '2019-11-12T02:28:00.000Z',
#   '2019-11-12T02:29:00.000Z',
#   '2019-11-12T02:30:00.000Z',
#   '2019-11-12T02:31:00.000Z',
#   '2019-11-12T02:32:00.000Z',
#   '2019-11-12T02:33:00.000Z',
#   '2019-11-12T02:34:00.000Z',
#   '2019-11-12T02:35:00.000Z',
#   '2019-11-12T02:36:00.000Z',
#   '2019-11-12T02:37:00.000Z',
#   '2019-11-12T02:38:00.000Z',
#   '2019-11-12T02:39:00.000Z',
#   '2019-11-12T02:40:00.000Z',
#   '2019-11-12T02:41:00.000Z',
#   '2019-11-12T02:42:00.000Z',
#   '2019-11-12T02:43:00.000Z',
#   '2019-11-12T02:44:00.000Z',
#   '2019-11-12T02:45:00.000Z',
#   '2019-11-12T02:46:00.000Z',
#   '2019-11-12T02:47:00.000Z',
#   '2019-11-12T02:48:00.000Z',
#   '2019-11-12T02:49:00.000Z',
#   '2019-11-12T02:50:00.000Z',
#   '2019-11-12T02:51:00.000Z',
#   '2019-11-12T02:52:00.000Z',
#   '2019-11-12T02:53:00.000Z',
#   '2019-11-12T02:54:00.000Z',
#   '2019-11-12T02:56:00.000Z',
#   '2019-11-12T02:57:00.000Z',
#   '2019-11-12T02:58:00.000Z',
#   '2019-11-12T02:59:00.000Z',
#   '2019-11-12T03:00:00.000Z',
#   '2019-11-12T03:01:00.000Z',
#   '2019-11-12T03:02:00.000Z',
#   '2019-11-12T03:03:00.000Z',
#   '2019-11-12T03:04:00.000Z',
#   '2019-11-12T03:05:00.000Z',
#   '2019-11-12T03:06:00.000Z',
#   '2019-11-12T03:07:00.000Z',
#   '2019-11-12T03:08:00.000Z',
#   '2019-11-12T03:09:00.000Z',
#   '2019-11-12T03:10:00.000Z',
#   '2019-11-12T03:11:00.000Z',
#   '2019-11-12T03:12:00.000Z',
#   '2019-11-12T03:13:00.000Z',
#   '2019-11-12T03:14:00.000Z',
#   '2019-11-12T03:15:00.000Z',
#   '2019-11-12T03:16:00.000Z',
#   '2019-11-12T03:17:00.000Z',
#   '2019-11-12T03:18:00.000Z',
#   '2019-11-12T03:19:00.000Z',
#   '2019-11-12T03:20:00.000Z',
#   '2019-11-12T03:21:00.000Z',
#   '2019-11-12T03:22:00.000Z',
#   '2019-11-12T03:23:00.000Z',
#   '2019-11-12T03:24:00.000Z',
#   '2019-11-12T03:25:00.000Z',
#   '2019-11-12T03:26:00.000Z',
#   '2019-11-12T03:27:00.000Z',
#   '2019-11-12T03:28:00.000Z',
#   '2019-11-12T03:29:00.000Z',
#   '2019-11-12T03:30:00.000Z',
#   '2019-11-12T03:31:00.000Z',
#   '2019-11-12T03:32:00.000Z',
#   '2019-11-12T03:33:00.000Z',
#   '2019-11-12T03:34:00.000Z',
#   '2019-11-12T03:35:00.000Z',
#   '2019-11-12T03:36:00.000Z',
#   '2019-11-12T03:37:00.000Z',
#   '2019-11-12T03:38:00.000Z',
#   '2019-11-12T03:40:00.000Z',
#   '2019-11-12T03:41:00.000Z',
#   '2019-11-12T03:42:00.000Z',
#   '2019-11-12T03:43:00.000Z',
#   '2019-11-12T03:44:00.000Z',
#   '2019-11-12T03:45:00.000Z',
#   '2019-11-12T03:46:00.000Z',
#   '2019-11-12T03:47:00.000Z',
#   '2019-11-12T03:48:00.000Z',
#   '2019-11-12T03:49:00.000Z',
#   '2019-11-12T03:50:00.000Z',
#   '2019-11-12T03:51:00.000Z',
#   '2019-11-12T03:52:00.000Z',
#   '2019-11-12T03:53:00.000Z',
#   '2019-11-12T03:54:00.000Z',
#   '2019-11-12T03:55:00.000Z',
#   '2019-11-12T03:56:00.000Z',
#   '2019-11-12T03:57:00.000Z',
#   '2019-11-12T03:58:00.000Z',
#   '2019-11-12T03:59:00.000Z',
#   '2019-11-12T04:00:00.000Z',
#   '2019-11-12T04:01:00.000Z',
#   '2019-11-12T04:02:00.000Z',
#   '2019-11-12T04:03:00.000Z',
#   '2019-11-12T04:04:00.000Z',
#   '2019-11-12T04:05:00.000Z',
#   '2019-11-12T04:06:00.000Z',
#   '2019-11-12T04:07:00.000Z',
#   '2019-11-12T04:08:00.000Z',
#   '2019-11-12T04:09:00.000Z',
#   '2019-11-12T04:10:00.000Z',
#   '2019-11-12T04:11:00.000Z',
#   '2019-11-12T04:12:00.000Z',
#   '2019-11-12T04:13:00.000Z',
#   '2019-11-12T04:14:00.000Z',
#   '2019-11-12T04:15:00.000Z',
#   '2019-11-12T04:16:00.000Z',
#   '2019-11-12T04:17:00.000Z',
#   '2019-11-12T04:18:00.000Z',
#   '2019-11-12T04:19:00.000Z',
#   '2019-11-12T04:20:00.000Z',
#   '2019-11-12T04:21:00.000Z',
#   '2019-11-12T04:22:00.000Z',
#   '2019-11-12T04:23:00.000Z',
#   '2019-11-12T04:24:00.000Z',
#   '2019-11-12T04:25:00.000Z',
#   '2019-11-12T04:26:00.000Z',
#   '2019-11-12T04:27:00.000Z',
#   '2019-11-12T04:28:00.000Z',
#   '2019-11-12T04:29:00.000Z',
#   '2019-11-12T04:30:00.000Z',
#   '2019-11-12T04:31:00.000Z',
#   '2019-11-12T04:32:00.000Z',
#   '2019-11-12T04:33:00.000Z',
#   '2019-11-12T04:34:00.000Z',
#   '2019-11-12T04:35:00.000Z',
#   '2019-11-12T04:36:00.000Z',
#   '2019-11-12T04:37:00.000Z',
#   '2019-11-12T04:38:00.000Z',
#   '2019-11-12T04:39:00.000Z',
#   '2019-11-12T04:40:00.000Z',
#   '2019-11-12T04:41:00.000Z',
#   '2019-11-12T04:42:00.000Z',
#   '2019-11-12T04:43:00.000Z',
#   '2019-11-12T04:44:00.000Z',
#   '2019-11-12T04:45:00.000Z',
#   '2019-11-12T04:46:00.000Z',
#   '2019-11-12T04:47:00.000Z',
#   '2019-11-12T04:48:00.000Z',
#   '2019-11-12T04:49:00.000Z',
#   '2019-11-12T04:50:00.000Z',
#   '2019-11-12T04:51:00.000Z',
#   '2019-11-12T04:52:00.000Z',
#   '2019-11-12T04:53:00.000Z',
#   '2019-11-12T04:54:00.000Z',
#   '2019-11-12T04:55:00.000Z',
#   '2019-11-12T04:56:00.000Z',
#   '2019-11-12T04:57:00.000Z',
#   '2019-11-12T04:58:00.000Z',
#   '2019-11-12T04:59:00.000Z',
#   '2019-11-12T05:00:00.000Z',
#   '2019-11-12T05:01:00.000Z',
#   '2019-11-12T05:02:00.000Z',
#   '2019-11-12T05:03:00.000Z',
#   '2019-11-12T05:04:00.000Z',
#   '2019-11-12T05:05:00.000Z',
#   '2019-11-12T05:06:00.000Z',
#   '2019-11-12T05:07:00.000Z',
#   '2019-11-12T05:08:00.000Z',
#   '2019-11-12T05:09:00.000Z',
#   '2019-11-12T05:10:00.000Z',
#   '2019-11-12T05:11:00.000Z',
#   '2019-11-12T05:12:00.000Z',
#   '2019-11-12T05:13:00.000Z',
#   '2019-11-12T05:14:00.000Z',
#   '2019-11-12T05:15:00.000Z',
#   '2019-11-12T05:16:00.000Z',
#   '2019-11-12T05:17:00.000Z',
#   '2019-11-12T05:18:00.000Z',
#   '2019-11-12T05:19:00.000Z',
#   '2019-11-12T05:20:00.000Z',
#   '2019-11-12T05:21:00.000Z',
#   '2019-11-12T05:22:00.000Z',
#   '2019-11-12T05:23:00.000Z',
#   '2019-11-12T05:24:00.000Z',
#   '2019-11-12T05:25:00.000Z',
#   '2019-11-12T05:30:00.000Z'],
#  [27.3,
#   27.3,
#   27.35,
#   27.4,
#   27.4,
#   27.4,
#   27.45,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.35,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.35,
#   27.4,
#   27.35,
#   27.4,
#   27.35,
#   27.35,
#   27.35,
#   27.35,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.35,
#   27.3,
#   27.3,
#   27.35,
#   27.3,
#   27.35,
#   27.35,
#   27.35,
#   27.3,
#   27.3,
#   27.3,
#   27.35,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.2,
#   27.2,
#   27.25,
#   27.2,
#   27.25,
#   27.2,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.2,
#   27.25,
#   27.2,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.2,
#   27.25,
#   27.2,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25],
#  [27.3,
#   27.35,
#   27.4,
#   27.4,
#   27.4,
#   27.45,
#   27.45,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.35,
#   27.35,
#   27.35,
#   27.35,
#   27.35,
#   27.35,
#   27.35,
#   27.35,
#   27.35,
#   27.35,
#   27.35,
#   27.35,
#   27.3,
#   27.35,
#   27.35,
#   27.35,
#   27.3,
#   27.35,
#   27.3,
#   27.35,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.2,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25],
#  [27.25,
#   27.3,
#   27.3,
#   27.4,
#   27.35,
#   27.4,
#   27.45,
#   27.35,
#   27.35,
#   27.4,
#   27.35,
#   27.4,
#   27.35,
#   27.4,
#   27.35,
#   27.4,
#   27.4,
#   27.4,
#   27.35,
#   27.4,
#   27.35,
#   27.4,
#   27.4,
#   27.35,
#   27.35,
#   27.35,
#   27.35,
#   27.4,
#   27.35,
#   27.3,
#   27.3,
#   27.35,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.2,
#   27.2,
#   27.2,
#   27.2,
#   27.2,
#   27.2,
#   27.2,
#   27.2,
#   27.2,
#   27.2,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.2,
#   27.2,
#   27.25,
#   27.2,
#   27.25,
#   27.2,
#   27.2,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.2,
#   27.2,
#   27.2,
#   27.2,
#   27.2,
#   27.2,
#   27.25,
#   27.25,
#   27.25,
#   27.2,
#   27.2,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25],
#  [27.3,
#   27.35,
#   27.4,
#   27.4,
#   27.4,
#   27.45,
#   27.45,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.35,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.35,
#   27.4,
#   27.4,
#   27.4,
#   27.4,
#   27.35,
#   27.4,
#   27.35,
#   27.4,
#   27.4,
#   27.35,
#   27.3,
#   27.35,
#   27.35,
#   27.35,
#   27.3,
#   27.3,
#   27.35,
#   27.3,
#   27.35,
#   27.35,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.2,
#   27.25,
#   27.2,
#   27.2,
#   27.2,
#   27.25,
#   27.25,
#   27.2,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.2,
#   27.25,
#   27.25,
#   27.25,
#   27.2,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.3,
#   27.25,
#   27.3,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.25,
#   27.25,
#   27.25,
#   27.3,
#   27.25,
#   27.3,
#   27.25,
#   27.25],
#  [793,
#   150,
#   250,
#   60,
#   213,
#   152,
#   10,
#   174,
#   23,
#   23,
#   8,
#   3,
#   6,
#   13,
#   23,
#   12,
#   6,
#   38,
#   30,
#   12,
#   62,
#   5,
#   4,
#   155,
#   22,
#   67,
#   5,
#   4,
#   144,
#   404,
#   15,
#   9,
#   49,
#   16,
#   15,
#   5,
#   30,
#   27,
#   12,
#   46,
#   16,
#   4,
#   16,
#   7,
#   54,
#   38,
#   115,
#   700,
#   35,
#   37,
#   99,
#   21,
#   14,
#   24,
#   10,
#   12,
#   65,
#   14,
#   13,
#   76,
#   77,
#   38,
#   50,
#   9,
#   55,
#   120,
#   20,
#   60,
#   75,
#   811,
#   291,
#   28,
#   21,
#   37,
#   42,
#   7,
#   16,
#   8,
#   732,
#   10,
#   5,
#   3,
#   34,
#   5,
#   1,
#   8,
#   6,
#   59,
#   62,
#   130,
#   19,
#   56,
#   122,
#   60,
#   18,
#   5,
#   23,
#   40,
#   55,
#   77,
#   33,
#   13,
#   7,
#   180,
#   87,
#   9,
#   38,
#   13,
#   93,
#   93,
#   148,
#   15,
#   13,
#   12,
#   15,
#   13,
#   44,
#   4,
#   8,
#   6,
#   7,
#   33,
#   20,
#   106,
#   43,
#   3,
#   29,
#   7,
#   4,
#   11,
#   9,
#   51,
#   5,
#   2,
#   7,
#   2,
#   34,
#   41,
#   35,
#   13,
#   6,
#   40,
#   39,
#   162,
#   5,
#   13,
#   85,
#   91,
#   36,
#   41,
#   22,
#   48,
#   51,
#   2,
#   12,
#   2,
#   44,
#   46,
#   23,
#   53,
#   59,
#   18,
#   33,
#   20,
#   60,
#   42,
#   9,
#   13,
#   198,
#   25,
#   61,
#   18,
#   32,
#   4,
#   5,
#   46,
#   12,
#   7,
#   3,
#   15,
#   31,
#   8,
#   5,
#   4,
#   38,
#   47,
#   103,
#   6,
#   21,
#   3,
#   49,
#   9,
#   5,
#   3,
#   8,
#   40,
#   8,
#   21,
#   60,
#   2,
#   93,
#   45,
#   8,
#   129,
#   120,
#   317,
#   10,
#   59,
#   15,
#   22,
#   175,
#   16,
#   24,
#   48,
#   53,
#   28,
#   139,
#   26,
#   3,
#   8,
#   8,
#   8,
#   7,
#   5,
#   54,
#   40,
#   12,
#   3,
#   5,
#   59,
#   33,
#   40,
#   41,
#   5,
#   29,
#   7,
#   44,
#   12,
#   31,
#   60,
#   68,
#   48,
#   160,
#   24,
#   56,
#   39,
#   72,
#   42,
#   24,
#   72,
#   43,
#   83,
#   19,
#   126,
#   63,
#   38,
#   45,
#   405,
#   62,
#   22,
#   112,
#   31,
#   18,
#   1588],
#  [793000,
#   150000,
#   250000,
#   60000,
#   213000,
#   152000,
#   10000,
#   174000,
#   23000,
#   23000,
#   8000,
#   3000,
#   6000,
#   13000,
#   23000,
#   12000,
#   6000,
#   38000,
#   30000,
#   12000,
#   62000,
#   5000,
#   4000,
#   155000,
#   22000,
#   67000,
#   5000,
#   4000,
#   144000,
#   404000,
#   15000,
#   9000,
#   49000,
#   16000,
#   15000,
#   5000,
#   30000,
#   27000,
#   12000,
#   46000,
#   16000,
#   4000,
#   16000,
#   7000,
#   54000,
#   38000,
#   115000,
#   700000,
#   35000,
#   37000,
#   99000,
#   21000,
#   14000,
#   24000,
#   10000,
#   12000,
#   65000,
#   14000,
#   13000,
#   76000,
#   77000,
#   38000,
#   50000,
#   9000,
#   55000,
#   120000,
#   20000,
#   60000,
#   75000,
#   811000,
#   291000,
#   28000,
#   21000,
#   37000,
#   42000,
#   7000,
#   16000,
#   8000,
#   732000,
#   10000,
#   5000,
#   3000,
#   34000,
#   5000,
#   1000,
#   8000,
#   6000,
#   59000,
#   62000,
#   130000,
#   19000,
#   56000,
#   122000,
#   60000,
#   18000,
#   5000,
#   23000,
#   40000,
#   55000,
#   77000,
#   33000,
#   13000,
#   7000,
#   180000,
#   87000,
#   9000,
#   38000,
#   13000,
#   93000,
#   93000,
#   148000,
#   15000,
#   13000,
#   12000,
#   15000,
#   13000,
#   44000,
#   4000,
#   8000,
#   6000,
#   7000,
#   33000,
#   20000,
#   106000,
#   43000,
#   3000,
#   29000,
#   7000,
#   4000,
#   11000,
#   9000,
#   51000,
#   5000,
#   2000,
#   7000,
#   2000,
#   34000,
#   41000,
#   35000,
#   13000,
#   6000,
#   40000,
#   39000,
#   162000,
#   5000,
#   13000,
#   85000,
#   91000,
#   36000,
#   41000,
#   22000,
#   48000,
#   51000,
#   2000,
#   12000,
#   2000,
#   44000,
#   46000,
#   23000,
#   53000,
#   59000,
#   18000,
#   33000,
#   20000,
#   60000,
#   42000,
#   9000,
#   13000,
#   198000,
#   25000,
#   61000,
#   18000,
#   32000,
#   4000,
#   5000,
#   46000,
#   12000,
#   7000,
#   3000,
#   15000,
#   31000,
#   8000,
#   5000,
#   4000,
#   38000,
#   47000,
#   103000,
#   6000,
#   21000,
#   3000,
#   49000,
#   9000,
#   5000,
#   3000,
#   8000,
#   40000,
#   8000,
#   21000,
#   60000,
#   2000,
#   93000,
#   45000,
#   8000,
#   129000,
#   120000,
#   317000,
#   10000,
#   59000,
#   15000,
#   22000,
#   175000,
#   16000,
#   24000,
#   48000,
#   53000,
#   28000,
#   139000,
#   26000,
#   3000,
#   8000,
#   8000,
#   8000,
#   7000,
#   5000,
#   54000,
#   40000,
#   12000,
#   3000,
#   5000,
#   59000,
#   33000,
#   40000,
#   41000,
#   5000,
#   29000,
#   7000,
#   44000,
#   12000,
#   31000,
#   60000,
#   68000,
#   48000,
#   160000,
#   24000,
#   56000,
#   39000,
#   72000,
#   42000,
#   24000,
#   72000,
#   43000,
#   83000,
#   19000,
#   126000,
#   63000,
#   38000,
#   45000,
#   405000,
#   62000,
#   22000,
#   112000,
#   31000,
#   18000,
#   1588000]]

# %%
wb = xw.Book()

sheet = wb.sheets[0]

sheet.range("A1").value = chart_data

# %% [markdown]
# # 但是結果卻出乎我們意料之外
#
# ![](https://drive.google.com/uc?export=download&id=1Cg304rzu-OMWVsZzYMwmZxOsEvmNEo5T)
#
# 原因是我們的二維串列的維度不對，**今天要將資料寫入一個二維的 Excel 工作表範圍，就需要賦值一個維度大小一樣的二維串列**
# zhuanzhi
# ![](https://drive.google.com/uc?export=download&id=1Bxulsz0NpTCYg86VWLBmgdirMeeG7MtE)
#
# 我們現在需要把二維串列做一個**轉置（Transpose）的處理，利用 Numpy 套件可以很快完成**
#
# ```python
# import numpy as np
#
# chart_data_ary = np.array(chart_data)
# # 轉置只需要針對一個 Numpy Array 執行 .T 即可
# chart_data_ary.T
# ```

# %% [markdown]
# 接下來我們將資料寫入 Excel 工作表：
#
# ```python
# sheet.range("A1").value = np.array(chart_data).T
# ```
#
# 經過轉置後的陣列，最後就會在 Excel 上呈現：
#
# ![](https://drive.google.com/uc?export=download&id=1vQsd6Mu_ZW9_GeBGXJp-8tBNIzL1ytf9)

# %%
# 將我們目前的程式碼整理成一個函數
import requests
import numpy as np
import time

def get_chart_data(stock_id, api_token):
    payload = {
        "symbolId": stock_id,
        "apiToken": api_token
    }

    res = requests.get("https://api.fugle.tw/realtime/v0/intraday/chart", params=payload)

    result = res.json()

    price_open = []
    price_high = []
    price_low = []
    price_close = []
    unit = []
    volume = []

    time_idx = result["data"]["chart"].keys()

    for idx in time_idx:
        data = result["data"]["chart"][idx]
        price_open.append(data["open"])
        price_high.append(data["high"])
        price_low.append(data["low"])
        price_close.append(data["close"])
        unit.append(data["unit"])
        volume.append(data["volume"])

    chart_data = [list(time_idx), price_open,price_high,price_low,price_close,unit,volume]
    chart_data_ary = np.array(chart_data).T
    
    return chart_data_ary

# %%
api_token = "f5d2cef7e50eb84a842b01d39c5d6a8b"

#api_token = "你的 fugle api 同行碼"
get_chart_data("0050", api_token)
# Out:
# array([['2019-11-12T01:01:00.000Z', '91.55', '91.8', ..., '91.8', '200',
#         '200000'],
#        ['2019-11-12T01:02:00.000Z', '91.95', '91.95', ..., '91.9', '32',
#         '32000'],
#        ['2019-11-12T01:03:00.000Z', '91.8', '91.85', ..., '91.85', '12',
#         '12000'],
#        ...,
#        ['2019-11-12T05:23:00.000Z', '91.9', '91.9', ..., '91.9', '2',
#         '2000'],
#        ['2019-11-12T05:24:00.000Z', '91.95', '91.95', ..., '91.95', '10',
#         '10000'],
#        ['2019-11-12T05:25:00.000Z', '92', '92', ..., '91.9', '15',
#         '15000']], dtype='<U24')

# %%
import xlwings xw

wb = xw.Book()
sheet = wb.sheets[0]

# %% [markdown]
# ## xlwings 的 chart 物件
#
# 用 `sheet.charts.add()` 產生新的圖表
#
# 上面的程式碼可以解讀成：我要在工作表的圖表集合新增一個圖表
#
# ```python
# # 在工作表新增一個空圖表物件
# chart = sheet.charts.add()
# # 這個圖標物件目前就像是一個空白的畫布
# # 我們需要丟一些資料進去，它才能夠畫出圖來
# chart
# ```
#
# ![](https://drive.google.com/uc?export=download&id=1oIrE9EK-QgyN4Vlhr87-nyOjaXkAQVLQ)

# %% [markdown]
# ```python
# last_cell = sheet.range("A1").end("down").end("right")
# last_cell
# # <Range [活頁簿1]工作表1!$G$264>
# ```

# %% [markdown]
# ## chart.set_source_data()
#
# 設定圖表的資料
#
# ```python
# chart.set_source_data(sheet.range("B1:E264"))
# ```
# ![](https://drive.google.com/uc?export=download&id=14z_gdJTn6LJnWcgI2t_McMiveD6vETro)
#
# 但是這依然不是我們要的圖表樣式...

# %%
chart.chart_type = "stock_ohlc"

# %% [markdown]
# ## 如何查詢 chart_type
#
# Excel 的圖表有非常多種，可以參考微軟官網的文件：[xlChartTypes 微軟官網](https://docs.microsoft.com/zh-tw/office/vba/api/Excel.XlChartType)
#
# ![](https://drive.google.com/uc?export=download&id=1dI2-htl5Enb7hsiix67QAnFKf0yLjDa0)
#
# ## 設定圖表位置
#
# ```python
# # 圓餅圖最上方等於 E1 儲存格的上邊
# chart.top = sheet.range("I1").top
# # 圓餅圖最左方等於 E1 儲存格的左邊
# chart.left = sheet.range("I1").left
# ```
#
# ![](https://drive.google.com/uc?export=download&id=18XmzHX7_z3eRBP4LQafefR8is6t3C4JM)

# %%
# 圓餅圖最上方等於 E1 儲存格的上邊
chart.top = sheet.range("I1").top
# 圓餅圖最左方等於 E1 儲存格的左邊
chart.left = sheet.range("I1").left

# %% [markdown]
# ## 完成版程式碼

# %%
import xlwings as xw
import requests
import numpy as np
import time

def get_chart_data(stock_id, api_token):
    payload = {
        "symbolId": stock_id,
        "apiToken": api_token
    }

    res = requests.get("https://api.fugle.tw/realtime/v0/intraday/chart", params=payload)

    result = res.json()

    price_open = []
    price_high = []
    price_low = []
    price_close = []
    unit = []
    volume = []

    time_idx = result["data"]["chart"].keys()

    for idx in time_idx:
        data = result["data"]["chart"][idx]
        price_open.append(data["open"])
        price_high.append(data["high"])
        price_low.append(data["low"])
        price_close.append(data["close"])
        unit.append(data["unit"])
        volume.append(data["volume"])

    chart_data = [list(time_idx), price_open,price_high,price_low,price_close,unit,volume]
    chart_data_ary = np.array(chart_data).T
    
    return chart_data_ary


api_token = "你的 fugle api 同行碼"

wb = xw.Book()
sheet = wb.sheets[0]
# 呼叫 api 截取資料
data = get_chart_data("2884", api_token)
sheet.range("A1").value = data
# 增加一個 chart 
chart = sheet.charts.add()
last_row = sheet.range("E1").end("down").row
# 選擇 B2 到 G264 這個範圍，
chart_data = sheet.range(f"B2:G{last_row}").value
# 將圖表的資料設定成該範圍内的資料
chart.set_source_data(sheet.range("B1:E264"))
# 最後將圖表的類別設定成 開盤-高-低-收盤股價圖
chart.chart_type = "stock_ohlc"
# 圓餅圖最上方等於 E1 儲存格的上邊
chart.top = sheet.range("I1").top
# 圓餅圖最左方等於 E1 儲存格的左邊
chart.left = sheet.range("I1").left
