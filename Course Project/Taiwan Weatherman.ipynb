# %% [markdown]
# ## Step.1 由API取得一周預報 ( json )
# * [Python’s Requests Library (Guide)](https://realpython.com/python-requests/)

# %%
import requests

url = "https://data.taipei/opendata/datalist/apiAccess?scope=resourceAquire&rid=e6831708-02b4-4ef8-98fa-4b4ce53459d9"

try:
    response = requests.get(url)
    full_data = response.json()

    # If the response was successful, no Exception will be raised
    response.raise_for_status()
except HTTPError as http_err:
    print(f'HTTP error occurred: {http_err}')
except Exception as err:
    print(f'Other error occurred: {err}')
else:
    print('Success!')
# Out:
# Success!

# %% [markdown]
# ## Step.2 處理資料
# We do not care about the weather of All the cities, choose some we're related to.

# %%
locs = ['臺北市','臺中市','新竹市']
forecasts = []
data = full_data["result"]["results"]

for loc in locs:
    row = []
    for dataset in data:
        if dataset['locationName'] == loc:
            row.append(dataset)
    forecasts.append(row)
forecasts
# Out:
# [[{'parameterName2': '10',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '8',
#    'parameterValue1': '2',
#    'locationName': '臺北市',
#    'endTime': '2020-02-18T06:00:00+08:00',
#    'startTime': '2020-02-17T18:00:00+08:00',
#    '_id': 1},
#   {'parameterName2': '15',
#    'parameterUnit2': 'C',
#    'parameterName1': '多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '8',
#    'parameterValue1': '4',
#    'locationName': '臺北市',
#    'endTime': '2020-02-18T18:00:00+08:00',
#    'startTime': '2020-02-18T06:00:00+08:00',
#    '_id': 2},
#   {'parameterName2': '14',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '12',
#    'parameterValue1': '2',
#    'locationName': '臺北市',
#    'endTime': '2020-02-19T06:00:00+08:00',
#    'startTime': '2020-02-18T18:00:00+08:00',
#    '_id': 3},
#   {'parameterName2': '22',
#    'parameterUnit2': 'C',
#    'parameterName1': '多雲時晴',
#    'parameterUnit3': 'C',
#    'parameterName3': '12',
#    'parameterValue1': '3',
#    'locationName': '臺北市',
#    'endTime': '2020-02-19T18:00:00+08:00',
#    'startTime': '2020-02-19T06:00:00+08:00',
#    '_id': 4},
#   {'parameterName2': '19',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '14',
#    'parameterValue1': '2',
#    'locationName': '臺北市',
#    'endTime': '2020-02-20T06:00:00+08:00',
#    'startTime': '2020-02-19T18:00:00+08:00',
#    '_id': 5},
#   {'parameterName2': '23',
#    'parameterUnit2': 'C',
#    'parameterName1': '多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '14',
#    'parameterValue1': '4',
#    'locationName': '臺北市',
#    'endTime': '2020-02-20T18:00:00+08:00',
#    'startTime': '2020-02-20T06:00:00+08:00',
#    '_id': 6},
#   {'parameterName2': '20',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '16',
#    'parameterValue1': '2',
#    'locationName': '臺北市',
#    'endTime': '2020-02-21T06:00:00+08:00',
#    'startTime': '2020-02-20T18:00:00+08:00',
#    '_id': 7},
#   {'parameterName2': '25',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '16',
#    'parameterValue1': '2',
#    'locationName': '臺北市',
#    'endTime': '2020-02-21T18:00:00+08:00',
#    'startTime': '2020-02-21T06:00:00+08:00',
#    '_id': 8},
#   {'parameterName2': '21',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '16',
#    'parameterValue1': '2',
#    'locationName': '臺北市',
#    'endTime': '2020-02-22T06:00:00+08:00',
#    'startTime': '2020-02-21T18:00:00+08:00',
#    '_id': 9},
#   {'parameterName2': '24',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '16',
#    'parameterValue1': '2',
#    'locationName': '臺北市',
#    'endTime': '2020-02-22T18:00:00+08:00',
#    'startTime': '2020-02-22T06:00:00+08:00',
#    '_id': 10},
#   {'parameterName2': '20',
#    'parameterUnit2': 'C',
#    'parameterName1': '多雲時晴',
#    'parameterUnit3': 'C',
#    'parameterName3': '17',
#    'parameterValue1': '3',
#    'locationName': '臺北市',
#    'endTime': '2020-02-23T06:00:00+08:00',
#    'startTime': '2020-02-22T18:00:00+08:00',
#    '_id': 11},
#   {'parameterName2': '26',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '16',
#    'parameterValue1': '2',
#    'locationName': '臺北市',
#    'endTime': '2020-02-23T18:00:00+08:00',
#    'startTime': '2020-02-23T06:00:00+08:00',
#    '_id': 12},
#   {'parameterName2': '22',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '17',
#    'parameterValue1': '2',
#    'locationName': '臺北市',
#    'endTime': '2020-02-24T06:00:00+08:00',
#    'startTime': '2020-02-23T18:00:00+08:00',
#    '_id': 13},
#   {'parameterName2': '27',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '17',
#    'parameterValue1': '2',
#    'locationName': '臺北市',
#    'endTime': '2020-02-24T18:00:00+08:00',
#    'startTime': '2020-02-24T06:00:00+08:00',
#    '_id': 14},
#   {'parameterName2': '22',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '17',
#    'parameterValue1': '2',
#    'locationName': '臺北市',
#    'endTime': '2020-02-25T06:00:00+08:00',
#    'startTime': '2020-02-24T18:00:00+08:00',
#    '_id': 15}],
#  [{'parameterName2': '13',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '9',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-18T06:00:00+08:00',
#    'startTime': '2020-02-17T18:00:00+08:00',
#    '_id': 46},
#   {'parameterName2': '20',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '9',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-18T18:00:00+08:00',
#    'startTime': '2020-02-18T06:00:00+08:00',
#    '_id': 47},
#   {'parameterName2': '16',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '12',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-19T06:00:00+08:00',
#    'startTime': '2020-02-18T18:00:00+08:00',
#    '_id': 48},
#   {'parameterName2': '23',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '12',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-19T18:00:00+08:00',
#    'startTime': '2020-02-19T06:00:00+08:00',
#    '_id': 49},
#   {'parameterName2': '19',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '14',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-20T06:00:00+08:00',
#    'startTime': '2020-02-19T18:00:00+08:00',
#    '_id': 50},
#   {'parameterName2': '25',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '14',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-20T18:00:00+08:00',
#    'startTime': '2020-02-20T06:00:00+08:00',
#    '_id': 51},
#   {'parameterName2': '21',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '17',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-21T06:00:00+08:00',
#    'startTime': '2020-02-20T18:00:00+08:00',
#    '_id': 52},
#   {'parameterName2': '25',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '17',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-21T18:00:00+08:00',
#    'startTime': '2020-02-21T06:00:00+08:00',
#    '_id': 53},
#   {'parameterName2': '21',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '16',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-22T06:00:00+08:00',
#    'startTime': '2020-02-21T18:00:00+08:00',
#    '_id': 54},
#   {'parameterName2': '25',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '16',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-22T18:00:00+08:00',
#    'startTime': '2020-02-22T06:00:00+08:00',
#    '_id': 55},
#   {'parameterName2': '22',
#    'parameterUnit2': 'C',
#    'parameterName1': '多雲時晴',
#    'parameterUnit3': 'C',
#    'parameterName3': '18',
#    'parameterValue1': '3',
#    'locationName': '臺中市',
#    'endTime': '2020-02-23T06:00:00+08:00',
#    'startTime': '2020-02-22T18:00:00+08:00',
#    '_id': 56},
#   {'parameterName2': '27',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '18',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-23T18:00:00+08:00',
#    'startTime': '2020-02-23T06:00:00+08:00',
#    '_id': 57},
#   {'parameterName2': '23',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '18',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-24T06:00:00+08:00',
#    'startTime': '2020-02-23T18:00:00+08:00',
#    '_id': 58},
#   {'parameterName2': '27',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '18',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-24T18:00:00+08:00',
#    'startTime': '2020-02-24T06:00:00+08:00',
#    '_id': 59},
#   {'parameterName2': '23',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '18',
#    'parameterValue1': '2',
#    'locationName': '臺中市',
#    'endTime': '2020-02-25T06:00:00+08:00',
#    'startTime': '2020-02-24T18:00:00+08:00',
#    '_id': 60}],
#  [{'parameterName2': '11',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '9',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-18T06:00:00+08:00',
#    'startTime': '2020-02-17T18:00:00+08:00',
#    '_id': 121},
#   {'parameterName2': '16',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '9',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-18T18:00:00+08:00',
#    'startTime': '2020-02-18T06:00:00+08:00',
#    '_id': 122},
#   {'parameterName2': '14',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '11',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-19T06:00:00+08:00',
#    'startTime': '2020-02-18T18:00:00+08:00',
#    '_id': 123},
#   {'parameterName2': '21',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '11',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-19T18:00:00+08:00',
#    'startTime': '2020-02-19T06:00:00+08:00',
#    '_id': 124},
#   {'parameterName2': '18',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '14',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-20T06:00:00+08:00',
#    'startTime': '2020-02-19T18:00:00+08:00',
#    '_id': 125},
#   {'parameterName2': '26',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '14',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-20T18:00:00+08:00',
#    'startTime': '2020-02-20T06:00:00+08:00',
#    '_id': 126},
#   {'parameterName2': '21',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '15',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-21T06:00:00+08:00',
#    'startTime': '2020-02-20T18:00:00+08:00',
#    '_id': 127},
#   {'parameterName2': '22',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '15',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-21T18:00:00+08:00',
#    'startTime': '2020-02-21T06:00:00+08:00',
#    '_id': 128},
#   {'parameterName2': '19',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '15',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-22T06:00:00+08:00',
#    'startTime': '2020-02-21T18:00:00+08:00',
#    '_id': 129},
#   {'parameterName2': '25',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '15',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-22T18:00:00+08:00',
#    'startTime': '2020-02-22T06:00:00+08:00',
#    '_id': 130},
#   {'parameterName2': '21',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '16',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-23T06:00:00+08:00',
#    'startTime': '2020-02-22T18:00:00+08:00',
#    '_id': 131},
#   {'parameterName2': '25',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '16',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-23T18:00:00+08:00',
#    'startTime': '2020-02-23T06:00:00+08:00',
#    '_id': 132},
#   {'parameterName2': '21',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '16',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-24T06:00:00+08:00',
#    'startTime': '2020-02-23T18:00:00+08:00',
#    '_id': 133},
#   {'parameterName2': '24',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '16',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-24T18:00:00+08:00',
#    'startTime': '2020-02-24T06:00:00+08:00',
#    '_id': 134},
#   {'parameterName2': '20',
#    'parameterUnit2': 'C',
#    'parameterName1': '晴時多雲',
#    'parameterUnit3': 'C',
#    'parameterName3': '16',
#    'parameterValue1': '2',
#    'locationName': '新竹市',
#    'endTime': '2020-02-25T06:00:00+08:00',
#    'startTime': '2020-02-24T18:00:00+08:00',
#    '_id': 135}]]

# %% [markdown]
# Clean these data
# 1. Select the columns we need, which are:
# ```python
# 'parameterName2', 'parameterName3', 'parameterName1', 'locationName', 'startTime'
# ```
# 2. Rename the columns thus the namings are ambiguous.
# ```python
# 'High (最高溫)', 'Low (最低溫)', 'Description (天氣概況)', 'City (縣市)', 'Date (起始日期時間)'
# ```
# > Warning: A value is trying to be set on a copy of a slice from a DataFrame
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Using pandas
import pandas as pd
df = pd.DataFrame(data)
df2 = df[['parameterName2', 'parameterName3', 'parameterName1', 'locationName', 'startTime']]
df2.rename(columns={'parameterName2':'High',
                    'parameterName3':'Low',
                    'parameterName1':'Description',
                    'locationName'  :'City',
                    'startTime'     :'Date'}, 
           inplace=True)
df2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#     High Low Description City                       Date
# 0     10   8        晴時多雲  臺北市  2020-02-17T18:00:00+08:00
# 1     15   8          多雲  臺北市  2020-02-18T06:00:00+08:00
# 2     14  12        晴時多雲  臺北市  2020-02-18T18:00:00+08:00
# 3     22  12        多雲時晴  臺北市  2020-02-19T06:00:00+08:00
# 4     19  14        晴時多雲  臺北市  2020-02-19T18:00:00+08:00
# ..   ...  ..         ...  ...                        ...
# 325   13  12          陰天  連江縣  2020-02-22T18:00:00+08:00
# 326   15  12        多雲時陰  連江縣  2020-02-23T06:00:00+08:00
# 327   13  13          多雲  連江縣  2020-02-23T18:00:00+08:00
# 328   16  13        晴時多雲  連江縣  2020-02-24T06:00:00+08:00
# 329   14  13        晴時多雲  連江縣  2020-02-24T18:00:00+08:00
#
# [330 rows x 5 columns]

# %% [markdown]
# Divid the big dataframe into small dataframe by **city**. Store them in a list.

# %%
# get 3 city's row
# https://datatofish.com/select-rows-pandas-dataframe/
df_list = []
for city in locs:
    df_list.append(df2.loc[df2['City'] == city])

# test forecast in Taichung
df_list[1]
# Out:
#    High Low Description City                       Date
# 45   13   9        晴時多雲  臺中市  2020-02-17T18:00:00+08:00
# 46   20   9        晴時多雲  臺中市  2020-02-18T06:00:00+08:00
# 47   16  12        晴時多雲  臺中市  2020-02-18T18:00:00+08:00
# 48   23  12        晴時多雲  臺中市  2020-02-19T06:00:00+08:00
# 49   19  14        晴時多雲  臺中市  2020-02-19T18:00:00+08:00
# 50   25  14        晴時多雲  臺中市  2020-02-20T06:00:00+08:00
# 51   21  17        晴時多雲  臺中市  2020-02-20T18:00:00+08:00
# 52   25  17        晴時多雲  臺中市  2020-02-21T06:00:00+08:00
# 53   21  16        晴時多雲  臺中市  2020-02-21T18:00:00+08:00
# 54   25  16        晴時多雲  臺中市  2020-02-22T06:00:00+08:00
# 55   22  18        多雲時晴  臺中市  2020-02-22T18:00:00+08:00
# 56   27  18        晴時多雲  臺中市  2020-02-23T06:00:00+08:00
# 57   23  18        晴時多雲  臺中市  2020-02-23T18:00:00+08:00
# 58   27  18        晴時多雲  臺中市  2020-02-24T06:00:00+08:00
# 59   23  18        晴時多雲  臺中市  2020-02-24T18:00:00+08:00

# %% [markdown]
# The data seems clean. But now we still have problem: the **Date** column is a string object and contains time zone.
# Create a method to parse string into datetime.
# >PS:  The api is free from Taipei City Government, so the data we get is quite hard dealing with.
#
# Sample input and output:
# ```python
# input: '2020-02-16T06:00:00+08:00',
# output: datetime.date(2020, 2, 16, 6, 0)
# ```

# %%
# datetime.datetime.strptime has problems with timezone parsing.
from dateutil import parser # deal with zones, not use
from datetime import datetime

def parse_date(in_str):
    in_str = in_str.split('T') # take of the character 'T'
    date_str = in_str[0]
    time_str = in_str[1].split('+')[0] # take of the time zone, including character '+'
    date = datetime.strptime(f"{date_str} {time_str}", '%Y-%m-%d %H:%M:%S')
    return date

# %% [markdown]
# By abserving the datetimes, the sequence looks the belows. Each day contains 2 records, 1 is forecast in noon, another is in night. To repesent the 高溫低溫圖, we only need 1 record for each day.
# 1. Keep the information of **date** and erase the **time** by lambda function.
# 2. Groupby the rows with same date. Select the highest temperature for column 'High', the lowest for 'Low'.
# 3. However, we want the other columns, so select the **first** element for 'City' and 'Description'.
# ```
# Id  High   Low	Description	City	Date
# 42	16	12	多雲時晴	臺中市	2020-02-17 06:00:00
# 43	13	10	晴時多雲	臺中市	2020-02-17 18:00:00
# 44	19	10	晴時多雲	臺中市	2020-02-18 06:00:00
# 45	16	12	晴時多雲	臺中市	2020-02-18 18:00:00
# ```
# into
# ```
#     Date      High	Low	City	Description
# 2020-02-17	16	10	臺中市	多雲時晴
# 2020-02-18	19	10	臺中市	晴時多雲
# ```
# There's an *'[SettingWithCopyWarning](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy)'* as well. Can't solve it. Help!

# %%
# parse the 'Date' colomn
# 不分白天晚上，只取預報的日期

# 都會噴warning 0.0，對dataframe不太了解
# adj_series = df_list[1]['Date'].apply(lambda s: parse_date(s))
# df_list[1].loc[:, ('Date')] = adj_series

for df in df_list:
    df.loc[:, ('Date')] = df['Date'].apply(lambda s: parse_date(s).date())
    
# test forecast in Taichung
df_list[1]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:576: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
#    High Low Description City        Date
# 45   13   9        晴時多雲  臺中市  2020-02-17
# 46   20   9        晴時多雲  臺中市  2020-02-18
# 47   16  12        晴時多雲  臺中市  2020-02-18
# 48   23  12        晴時多雲  臺中市  2020-02-19
# 49   19  14        晴時多雲  臺中市  2020-02-19
# 50   25  14        晴時多雲  臺中市  2020-02-20
# 51   21  17        晴時多雲  臺中市  2020-02-20
# 52   25  17        晴時多雲  臺中市  2020-02-21
# 53   21  16        晴時多雲  臺中市  2020-02-21
# 54   25  16        晴時多雲  臺中市  2020-02-22
# 55   22  18        多雲時晴  臺中市  2020-02-22
# 56   27  18        晴時多雲  臺中市  2020-02-23
# 57   23  18        晴時多雲  臺中市  2020-02-23
# 58   27  18        晴時多雲  臺中市  2020-02-24
# 59   23  18        晴時多雲  臺中市  2020-02-24

# %%
forecasts = []
for df in df_list:
    result_df = df.groupby(['Date']).agg({'High':max, 
                                               'Low' :min,
                                               'City':'first',
                                               'Description' :'first'}) 
    forecasts.append(result_df)

# test forecast in Taichung
forecasts[1]
# Out:
#            High Low City Description
# Date
# 2020-02-17   13   9  臺中市        晴時多雲
# 2020-02-18   20  12  臺中市        晴時多雲
# 2020-02-19   23  12  臺中市        晴時多雲
# 2020-02-20   25  14  臺中市        晴時多雲
# 2020-02-21   25  16  臺中市        晴時多雲
# 2020-02-22   25  16  臺中市        晴時多雲
# 2020-02-23   27  18  臺中市        晴時多雲
# 2020-02-24   27  18  臺中市        晴時多雲

# %% [markdown]
# ## Step.3 將預報寫進Excel檔案

# %%
import xlwings as xw
wb = xw.Book()

# %%
for idx, city in enumerate(locs):
    # For each city, create a sheet
    sheet = wb.sheets.add(name=city, after=wb.sheets[-1])
    
    # Write forecast data (dataframe) in sheet
    sheet.range("A1").value = forecasts[idx]
    
    # Draw the temperature line chart
    chart = sheet.charts.add() # 在工作表新增一個空圖表物件
    chart.top = sheet.range('G1').top
    chart.left = sheet.range('G1').left
    
    chart.set_source_data(sheet.range('A1:C1').expand("down"))
    chart.chart_type = 'line'
